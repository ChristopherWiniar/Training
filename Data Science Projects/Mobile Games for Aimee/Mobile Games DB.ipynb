# %%
# !pip install matplotlib

# %%
import pandas as pd
df = pd.read_csv('best-selling-mobile-games.csv')
df.shape
# Out:
# (104, 5)

# %%
df.values
# Out:
# array([['Honor of Kings / Arena of Valor', 14667500000, '2015-11-26',
#         'Tencent Games', 'MOBA'],
#        ['Monster Strike', 10000000000, '2013-08-08', 'Mixi',
#         'Puzzle / RPG / Strategy'],
#        ['PUBG Mobile', 9000000000, '2018-03-19',
#         'Tencent Games / Krafton / VNG Games', 'Battle royale'],
#        ['Puzzle & Dragons', 8578340000, '2012-02-20',
#         'GungHo Online Entertainment', 'RPG / Puzzle'],
#        ['Clash of Clans', 8000000000, '2012-08-02',
#         'Supercell (Tencent)', 'Strategy'],
#        ['Pokémon Go', 7760000000, '2016-07-06',
#         'Niantic / The Pokémon Company', 'Augmented reality'],
#        ['Candy Crush Saga', 7456000000, '2012-11-14',
#         'King (Activision Blizzard)', 'Puzzle'],
#        ['Fate/Grand Order', 6300000000, '2015-07-30',
#         'Aniplex (Sony Music Entertainment Japan)', 'RPG'],
#        ['Fantasy Westward Journey', 4700000000, '2015-03-26', 'NetEase',
#         'MMORPG'],
# ...
