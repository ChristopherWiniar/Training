# %%
# Building a prediction model for my wife, who is starting e-commerce shop in Poland. Unfortunately data will have to flow from multiple streams, Allegro, our own Website, Webay, OLX. TBA

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('Ecommerce Customers.csv')

x = data.iloc[:, 3:7].values
X = data.iloc[:, 3:4].values
y = data.iloc[:,7:].values
#Looking for rependencies
#x
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('Ecommerce Customers.csv')

x = data.iloc[:, 3:7].values
X = data.iloc[:, 3:4].values
Y = data.iloc[:, 4:5].values
Z = data.iloc[:, 5:6].values
A = data.iloc[:, 6:7].values
y = data.iloc[:,7:].values

figure = plt.figure()
axis = figure.add_axes([0,0,1,1])
axis.scatter(A, y, color = 'blue')
#There is no relation between X, Y, Z but we can see one in A which is Lenght of membership and Yearly ammount spent.

# %%
#Splitting dataset
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 0)
#y_train
regression = LinearRegression()
regression.fit(x_train, y_train)
y_predict = regression.predict(x_test)
y_predict[1]
# Out:
# LinearRegression()

# %%
y_test[1]
